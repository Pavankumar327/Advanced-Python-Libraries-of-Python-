# %% [markdown]
# <a href="https://colab.research.google.com/github/Pavankumar327/Advanced-Python-Libraries-of-Python-/blob/main/Seaborn_data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
import seaborn as sns
titanic=sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import seaborn as sns
penguins=sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# # relational plot

# %%
# without kind
sns.relplot(x='age',y='fare',data=titanic)

# %% [markdown]
# ## 1.scatter plot

# %%
# with kind
# hue is used for colouring the particular column that we require
sns.relplot(x='age',y='fare',data=titanic,kind='scatter',hue='pclass')# default kind is scatter

# %%
sns.relplot(x='age',y='fare',data=titanic,kind='scatter',hue='survived')

# %%
# palette is used for colouring the data set with user input colors
sns.relplot(x='age',y='fare',data=titanic,kind='scatter',hue='survived',palette='YlOrRd',)

# %% [markdown]
# ## 2.line plot

# %%
# By default scatter plot because kind is not mentioned
sns.relplot(x='age',y='fare',data=titanic,hue='pclass')

# %%
# hue="pclass"
sns.relplot(x='age',y='fare',data=titanic,kind='line',hue='pclass')

# %%
# hue="survived"
sns.relplot(x='age',y='fare',data=titanic,kind='line',hue='survived')

# %%
sns.relplot(x='age',y='fare',data=titanic,kind='line',hue='survived', palette='YlOrRd')

# %% [markdown]
# # distribution plot

# %% [markdown]
# ### 1.Histogram plot in seaborn

# %%
sns.__version__
# Out:
# '0.11.2'

# %%
import matplotlib.pyplot as plt
sns.histplot(data=penguins, x="flipper_length_mm", hue="species",multiple="stack" )
plt.title("Penguins data Histogram",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Penguins data Histogram')

# %% [markdown]
# ### 2.kde plot

# %%
import seaborn as sns # without title 
sns.kdeplot(data=penguins,x="flipper_length_mm",hue="species",multiple='stack')

# %%
#kdeplot with title 
import seaborn as sns
sns.kdeplot(data=penguins,x="flipper_length_mm",hue="species",multiple="stack" )
plt.title("Distribution plot of penguins ", fontsize=18)
# Out:
# Text(0.5, 1.0, 'Distribution plot of penguins ')

# %%
iris=sns.load_dataset("iris")
iris.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
# without hue
sns.kdeplot(data=iris,x="sepal_width", multiple='stack')

# %%
# with hue
sns.kdeplot(data=iris,x="sepal_width",hue='species', multiple='stack')

# %%
# hue is used for coloring the column data that we require (ex.hue='species') here species is the data that we are using and colouring
sns.displot(data=penguins,x="flipper_length_mm",hue="species",multiple='stack',kind='kde')

# %%
sns.displot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack",kind='hist')  # kind='hist'

# %%
# column features in distribution plot of seaborn
sns.displot(data=penguins,x="flipper_length_mm",hue="species",col='species',kind='kde')

# %%
# row manner in distribution plot in seaborn
sns.displot(data=penguins,x="flipper_length_mm",hue="species",row='species',kind='kde')

# %%
# row = 'sex'
sns.displot(data=penguins,x="flipper_length_mm",hue="species",row='sex',kind='kde')

# %% [markdown]
# ### 3.ecdf plot
#   Multiple is not supported because Line-2D  object has no property multiple in ecdf plot and dis plot also

# %%
# no multiple is used here
sns.ecdfplot(data=penguins,x="flipper_length_mm",hue="species")

# %%
# ex.for not supported multiple in ecdf plot 
sns.ecdfplot(data=penguins,x="flipper_length_mm",hue="species", multiple='species')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-7814ab1a9b32> in <module>()
# ----> 1 sns.ecdfplot(data=penguins,x="flipper_length_mm",hue="species", multiple='species')
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py in ecdfplot(data, x, y, hue, weights, stat, complementary, palette, hue_order, hue_norm, log_scale, legend, ax, **kwargs)
#    1998         estimate_kws=estimate_kws,
#    1999         legend=legend,
# -> 2000         **kwargs,
#    2001     )
#    2002
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py in plot_univariate_ecdf(self, estimate_kws, legend, **plot_kws)
#    1293             # Draw the line for this subset
#    1294             ax = self._get_axes(sub_vars)
# -> 1295             artist, = ax.plot(*plot_args, **artist_kws)
# ...

# %%
# kind= 'ecdf'
sns.displot(data=penguins,x="flipper_length_mm",hue="species",kind='ecdf')

# %%
# column='species'
sns.displot(data=penguins,x="flipper_length_mm",hue="species",col='species',kind='ecdf')

# %%
# row='species'
sns.displot(data=penguins,x="flipper_length_mm",hue="species",row='species',kind='ecdf')

# %%
# row='sex'
sns.displot(data=penguins,x="flipper_length_mm",hue="species",row='sex',kind='ecdf')

# %% [markdown]
# ### 4.rug plot

# %%
# without hue
sns.rugplot(data=penguins,x="flipper_length_mm")

# %%
# with hue
sns.rugplot(data=penguins,x="flipper_length_mm",hue="species")

# %%
# multiple is not supported in rugplot also(ex.below figure)
sns.rugplot(data=penguins,x="flipper_length_mm",hue="species", multiple='species')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-61999b5b9b58> in <module>()
# ----> 1 sns.rugplot(data=penguins,x="flipper_length_mm",hue="species", multiple='species')
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py in rugplot(x, height, axis, ax, data, y, hue, palette, hue_order, hue_norm, expand_margins, legend, a, **kwargs)
#    2125     p._attach(ax)
#    2126
# -> 2127     p.plot_rug(height, expand_margins, legend, **kwargs)
#    2128
#    2129     return ax
#
# ...

# %%
sns.rugplot(data=penguins,x="flipper_length_mm",hue="sex")
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/colors.py:263: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   c = np.array(c)

# %% [markdown]
# ## Axes level functions

# %%
f, axs = plt.subplots(1, 2, figsize=(8, 4), gridspec_kw=dict(width_ratios=[4, 3]))
sns.scatterplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species", ax=axs[0])
sns.histplot(data=penguins, x="species", hue="species", shrink=.8, alpha=.8, legend=False, ax=axs[1])
f.tight_layout()

# %%
# shrink is the width size of the histograph/
f, axs = plt.subplots(1, 2, figsize=(8, 4), gridspec_kw=dict(width_ratios=[4, 3]))
sns.scatterplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species", ax=axs[0])
sns.histplot(data=penguins, x="species", hue="species", shrink=.2, alpha=.8, legend=False, ax=axs[1])
f.tight_layout()

# %% [markdown]
# # joint plot

# %%
sns.jointplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species")

# %% [markdown]
# # pair plot

# %%
penguins.head(3)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female

# %%
sns.pairplot(data=penguins,hue="island")

# %%
sns.pairplot(data=penguins, hue="sex")

# %% [markdown]
# # categorical plot(catplot)

# %% [markdown]
# ## 1.box plot

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# without kind
sns.catplot(x="day",y="total_bill",data=tips)

# %%
# with kind (kind='box')
sns.catplot(x="day",y="total_bill",kind="box",data=tips)

# %%
# box plot with kind,columns
sns.catplot(x="day",y="total_bill",kind="box",data=tips,col='time')

# %% [markdown]
# ## 2.violin plot

# %%
# without kind
sns.catplot(x="day",y="total_bill",kind="violin",data=tips)

# %%
# violin plot with kind(kind='violin')
sns.catplot(x="day",y="total_bill",hue='sex',kind="violin",data=tips)

# %% [markdown]
# ## 3.Swarm plot

# %%
# without kind 
sns.catplot(x="day",y="total_bill",kind="swarm",data=tips)

# %%
# with kind 
sns.catplot(x="day",y="total_bill",hue='sex',kind="swarm",data=tips)

# %% [markdown]
# ## 4.strip plot

# %%
# without kind 
sns.catplot(x="day",y="total_bill",kind="strip",data=tips)

# %%
# with kind 
sns.catplot(x="day",y="total_bill",hue='sex',kind="strip",data=tips)

# %% [markdown]
# ## 5.point plot

# %%
# without kind
sns.catplot(x="day",y="total_bill",kind="point",data=tips)

# %%
# with kind
sns.catplot(x="day",y="total_bill",hue='sex',kind="point",data=tips)

# %% [markdown]
# ## 6.bar plot

# %%
# without kind
sns.catplot(x="day",y="total_bill",kind="bar",data=tips)

# %%
# with kind
sns.catplot(x="day",y="total_bill",hue='sex',kind="bar",data=tips)

# %% [markdown]
# # Heat map plotting

# %% [markdown]
# A heatmap is a plot of rectangular data as a color-encoded matrix.
#  As parameter it takes a 2D dataset. That dataset can be coerced into an ndarray.
#
# This is a great way to visualize data, because it can show the relation between variabels including time.
#  For instance, the number of fligths through the years.

# %% [markdown]
# ###Syntax: seaborn.heatmap(data, *, vmin=None, vmax=None, cmap=None, center=None, annot_kws=None, linewidths=0, linecolor=’white’, cbar=True, **kwargs)
#
# ###Important Parameters:
#
# data: 2D dataset that can be coerced into an ndarray.
#
# vmin, vmax: Values to anchor the colormap, otherwise they are inferred from the data and other keyword arguments.
#
# cmap: The mapping from data values to color space.
#
# center: The value at which to center the colormap when plotting divergent data.
#
# annot: If True, write the data value in each cell.
#
# fmt: String formatting code to use when adding annotations.
#
# linewidths: Width of the lines that will divide each cell.
#
# linecolor: Color of the lines that will divide each cell.
#
# cbar: Whether to draw a colorbar.
#
# All the parameters except data are optional.
#
# Returns: An object of type matplotlib.axes._subplots.AxesSubplot

# %%
# heat map of flights or aeroplanes
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
flights = sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")
ax = sns.heatmap(flights)
plt.title("Heatmap Flight Data")
plt.show()

# %%
# heat map of random numbers based on numpy 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

np.random.seed(0)
sns.set()
uniform_data = np.random.rand(10,12)# (vertical left, horizontal)
ax = sns.heatmap(uniform_data, vmin=
0, vmax=1)#(vertical right min, vertical right max)
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

np.random.seed(0)
sns.set()
uniform_data = np.random.rand(10,12)# (vertical left, horizontal)
ax = sns.heatmap(uniform_data, vmin=
2, vmax=3)#(vertical right min, vertical right max)
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

np.random.seed(1)
sns.set()
uniform_data = np.random.rand(10,12)# (vertical left, horizontal)
ax = sns.heatmap(uniform_data, vmin=
0.5, vmax=2)#(vertical right min, vertical right max)
plt.show()

# %% [markdown]
# ###Heatmap colors
# The heatmap colors plot below uses random data again. This time it’s using a different color map (cmap), with the ‘Blues’ palette which as nothing but colors of blue. It also uses square blocks

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.DataFrame(np.random.randn(50).reshape(5,10)) # reshaping the array of size 50 into shape (5,10)
corr = df.corr()

ax1 = sns.heatmap(corr, cbar=0, linewidths=2,vmax=1, vmin=0, square=True, cmap='Blues')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#generating a 2-D 10*10 matrix of random numbers from 1 to 100
data = np.random.randint(low = 1,
                         high=100,
                         size=(10,10))
print ("data to be plotted:\n")
print (data)
#plotting the heat map
hm=sns.heatmap(data=data)
#displaying the plotted heatmap
plt.show()
# Out:
# data to be plotted:
#
# [[53 77 69 46 65 90 41  8  8 34]
#  [59  8 35  5  6 62 51 77 46 97]
#  [22 93 72 93 26 98  2 14 39 86]
#  [28 39 85 34  2 32 39 29 76 32]
#  [52 67 68 33 75 33 98  6  1 38]
#  [73 44 25 17 97 97 42 25 22 28]
#  [47 36 63 69 63 33 46 89 43 58]
#  [26 33 34  7 66 52 32  8 14  4]
#  [29 16 30 67 62 84 97 59 83 35]
#  [31 58 97 50 47 84 42 21 41 51]]

# %% [markdown]
# ##Anchoring the colormap:
#
# If we set the vmin value to 30 and the vmax value to 70, then only the cells with values between 30 and 70 will be displayed.
# This is called anchoring the colormap.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#generating a 2-D 10*10 matrix of random numbers from 1 to 100
data = np.random.randint(low = 1,
                         high=100,
                         size=(10,10))
vmin=30
vmax=70
print ("data to be plotted:\n")
print (data)
#plotting the heat map
hm=sns.heatmap(data,vmin=vmin,vmax=vmax)
#displaying the plotted heatmap
plt.show()
# Out:
# data to be plotted:
#
# [[91 84 40 99 16 38 97 37 99  2]
#  [33 31  8 51 51 33 44 42 70  2]
#  [98 52 31 83 50 82 83 96 72 22]
#  [19 47 45 92 10  5 78 64 24 96]
#  [60 65 83 32  2 85 79 69 55 26]
#  [84 28 57 93  9 56 77 47 50 12]
#  [ 9 62 75 24 89 90 83 83  6 43]
#  [47 22 52 74 43 14 19 24 46 96]
#  [53 34 55 15 58 62 41 73 66 23]
#  [ 3 87  2 73 52 72 88 78 63 49]]

# %% [markdown]
# ##Choosing the colormap:
#
# In this, we will be looking at the cmap parameter. Matplotlib provides us with multiple colormaps, you can look at all of them here.
# In our example, we’ll be using tab20.

# %%
import numpy as np 

import seaborn as sn 

import matplotlib.pyplot as plt 

  
# generating 2-D 10x10 matrix of random numbers 
# from 1 to 100 

data = np.random.randint(low=1, 

                         high=100, 

                         size=(10, 10)) 

  
# setting the parameter values 

cmap = "tab20"

  
# plotting the heatmap 

hm = sn.heatmap(data=data, 

                cmap=cmap) 

  
# displaying the plotted heatmap 
plt.show()

# %% [markdown]
# ###Centering the colormap:
# Centering the cmap to 0 by passing the center parameter as 0.

# %%
import numpy as np 

import seaborn as sn 

import matplotlib.pyplot as plt 

  
# generating 2-D 10x10 matrix of random numbers 
# from 1 to 100 

data = np.random.randint(low=1, 

                         high=100, 

                         size=(10, 10)) 

  
# setting the parameter values 

cmap = "tab20"

center = 0

  
# plotting the heatmap 

hm = sn.heatmap(data=data, 

                cmap=cmap, 

                center=center) 

  
# displaying the plotted heatmap 
plt.show()

# %% [markdown]
# ###Displaying the cell values:
#
# If we want to display the value of the cells, then we pass the parameter annot as True. fmt is used to select the datatype of the contents of the cells displayed.

# %%
import numpy as np 

import seaborn as sn 

import matplotlib.pyplot as plt 

  
# generating 2-D 10x10 matrix of random numbers 
# from 1 to 100 

data = np.random.randint(low=1, 

                         high=100, 

                         size=(10, 10)) 

  
# setting the parameter values 

annot = True

  
# plotting the heatmap 

hm = sn.heatmap(data=data, 

                annot=annot) 

  
# displaying the plotted heatmap 
plt.show()

# %% [markdown]
# ###Customizing the separating line:
#
# We can change the thickness and the color of the lines separating the cells using the linewidths and linecolor parameters respectively.

# %%
import numpy as np 

import seaborn as sn 

import matplotlib.pyplot as plt 

  
# generating 2-D 10x10 matrix of random numbers 
# from 1 to 100 

data = np.random.randint(low=1, 

                         high=100, 

                         size=(10, 10)) 

  
# setting the parameter values 

linewidths = 2

linecolor = "yellow"

  
# plotting the heatmap 

hm = sn.heatmap(data=data, 

                linewidths=linewidths, 

                linecolor=linecolor) 

  
# displaying the plotted heatmap 
plt.show()

# %% [markdown]
# ###Hiding the colorbar
#
# We can disable the colorbar by setting the cbar parameter to False.

# %%
import numpy as np 

import seaborn as sn 

import matplotlib.pyplot as plt 

  
# generating 2-D 10x10 matrix of random numbers 
# from 1 to 100 

data = np.random.randint(low=1, 

                         high=100, 

                         size=(10, 10)) 

  
# setting the parameter values 

cbar = False

  
# plotting the heatmap 

hm = sn.heatmap(data=data, 

                cbar=cbar) 

  
# displaying the plotted heatmap 
plt.show()

# %% [markdown]
# ###Removing the labels:
#
# We can disable the x-label and the y-label by passing False in the xticklabels and yticklabels parameters respectively.

# %%
import numpy as np 

import seaborn as sn 

import matplotlib.pyplot as plt 

  
# generating 2-D 10x10 matrix of random numbers 
# from 1 to 100 

data = np.random.randint(low=1, 

                         high=100, 

                         size=(10, 10)) 

  
# setting the parameter values 

xticklabels = False

yticklabels = False

  
# plotting the heatmap 

hm = sn.heatmap(data=data, 

                xticklabels=xticklabels, 

                yticklabels=yticklabels) 

  
# displaying the plotted heatmap 
plt.show()

# %%
# using different colour maps
ax = sns.heatmap(flights, cmap="YlGnBu")

# %%
# centre the colormap at a specific value
ax = sns.heatmap(flights, center=flights.loc["Jan", 1955])

# %%
#plotting every other column label and don't plot row labels
data = np.random.randn(50, 20)
ax = sns.heatmap(data, xticklabels=2, yticklabels=False)

# %%
# using different axes for the colorbars
grid_kws = {"height_ratios": (.9, .05), "hspace": .3}
f, (ax, cbar_ax) = plt.subplots(2, gridspec_kw=grid_kws)
ax = sns.heatmap(flights, ax=ax,
                cbar_ax=cbar_ax,
               cbar_kws={"orientation": "horizontal"})

# %%
# using a  mask to plot only part of a matrix
corr = np.corrcoef(np.random.randn(10, 200))
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
   f, ax = plt.subplots(figsize=(7, 5))
   ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True)
